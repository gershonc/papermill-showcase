# %%
import papermill as pm
from datetime import datetime
now = datetime.now()

# %%
from IPython import display
display.Image("papermill_overview.png")

# %% [markdown]
# ## Running via Jupyter

# %%
name = "Gershon"
run_time = now.strftime("%d/%m/%Y %H:%M:%S")
res = pm.execute_notebook(
    'papermlll_example.ipynb',
    'papermill_{name}.ipynb',
    parameters = dict(name=name, run_time=run_time)
)
# Out:
# Executing:   0%|          | 0/3 [00:00<?, ?cell/s]

# %% [markdown]
# ## Running in CLI

# %%
#!papermill -p name Gershon papermlll_example.ipynb papermill_Gershon.ipynb
